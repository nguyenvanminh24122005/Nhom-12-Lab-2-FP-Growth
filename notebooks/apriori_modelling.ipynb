# %% [markdown]
# # Apriori Modelling
#
# ## Mục tiêu
# - Áp dụng thuật toán Apriori để tìm các tập sản phẩm thường được mua cùng nhau.
# - Sinh ra các luật kết hợp (association rules).
# - Phân tích và rút ra insight kinh doanh.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

DATA_PATH = "../data/basket_bool.parquet"

basket_bool = pd.read_parquet(DATA_PATH)

print("Basket loaded:", basket_bool.shape)
# Out:
# Basket loaded: (18019, 4007)

# %%
frequent_itemsets = apriori(
    basket_bool,
    min_support=0.03,
    use_colnames=True
)

print("Số frequent itemsets:", frequent_itemsets.shape)
frequent_itemsets.head()
# Out:
# c:\Users\admin\anaconda3\envs\shopping_env\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Số frequent itemsets: (145, 2)
#     support                           itemsets
# 0  0.047450           (6 RIBBONS RUSTIC CHARM)
# 1  0.032244  (60 CAKE CASES VINTAGE CHRISTMAS)
# 2  0.041789      (60 TEATIME FAIRY CAKE CASES)
# 3  0.030801   (72 SWEETHEART FAIRY CAKE CASES)
# 4  0.048615       (ALARM CLOCK BAKELIKE GREEN)

# %%
rules = association_rules(
    frequent_itemsets,
    metric="confidence",
    min_threshold=0.5
)

rules = rules.sort_values(by="lift", ascending=False)

print("Số luật sinh ra:", rules.shape)
rules.head()
# Out:
# Số luật sinh ra: (15, 14)
#                              antecedents                          consequents  \
# 4      (GREEN REGENCY TEACUP AND SAUCER)     (PINK REGENCY TEACUP AND SAUCER)
# 5       (PINK REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 13    (ROSES REGENCY TEACUP AND SAUCER )     (PINK REGENCY TEACUP AND SAUCER)
# 14      (PINK REGENCY TEACUP AND SAUCER)   (ROSES REGENCY TEACUP AND SAUCER )
# 2   (GARDENERS KNEELING PAD CUP OF TEA )  (GARDENERS KNEELING PAD KEEP CALM )
#
#     antecedent support  consequent support   support  confidence       lift  \
# 4             0.051723            0.038959  0.031966    0.618026  15.863541
# 5             0.038959            0.051723  0.031966    0.820513  15.863541
# 13            0.053055            0.038959  0.030246    0.570084  14.632960
# 14            0.038959            0.053055  0.030246    0.776353  14.632960
# 2             0.041623            0.049836  0.030024    0.721333  14.474059
#
#     representativity  leverage  conviction  zhangs_metric   jaccard  \
# 4                1.0  0.029951    2.515984       0.988068  0.544423
# 5                1.0  0.029951    5.283257       0.974945  0.544423
# 13               1.0  0.028179    2.235414       0.983860  0.489668
# 14               1.0  0.028179    4.234110       0.969429  0.489668
# 2                1.0  0.027950    3.409678       0.971341  0.488708
#
#     certainty  kulczynski
# 4    0.602541    0.719269
# 5    0.810723    0.719269
# 13   0.552656    0.673218
# 14   0.763823    0.673218
# 2    0.706717    0.661892

# %%
strong_rules = rules[
    (rules["confidence"] >= 0.6) &
    (rules["lift"] >= 1.5)
]

print("Số luật mạnh:", strong_rules.shape)
strong_rules.head()
# Out:
# Số luật mạnh: (12, 14)
#                              antecedents  \
# 4      (GREEN REGENCY TEACUP AND SAUCER)
# 5       (PINK REGENCY TEACUP AND SAUCER)
# 14      (PINK REGENCY TEACUP AND SAUCER)
# 2   (GARDENERS KNEELING PAD CUP OF TEA )
# 3    (GARDENERS KNEELING PAD KEEP CALM )
#
#                              consequents  antecedent support  \
# 4       (PINK REGENCY TEACUP AND SAUCER)            0.051723
# 5      (GREEN REGENCY TEACUP AND SAUCER)            0.038959
# 14    (ROSES REGENCY TEACUP AND SAUCER )            0.038959
# 2    (GARDENERS KNEELING PAD KEEP CALM )            0.041623
# 3   (GARDENERS KNEELING PAD CUP OF TEA )            0.049836
#
#     consequent support   support  confidence       lift  representativity  \
# 4             0.038959  0.031966    0.618026  15.863541               1.0
# 5             0.051723  0.031966    0.820513  15.863541               1.0
# 14            0.053055  0.030246    0.776353  14.632960               1.0
# 2             0.049836  0.030024    0.721333  14.474059               1.0
# 3             0.041623  0.030024    0.602450  14.474059               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 4   0.029951    2.515984       0.988068  0.544423   0.602541    0.719269
# 5   0.029951    5.283257       0.974945  0.544423   0.810723    0.719269
# 14  0.028179    4.234110       0.969429  0.489668   0.763823    0.673218
# 2   0.027950    3.409678       0.971341  0.488708   0.706717    0.661892
# 3   0.027950    2.410708       0.979737  0.488708   0.585184    0.661892

# %%
OUTPUT_PATH = "../data/apriori_rules.csv"

strong_rules.to_csv(OUTPUT_PATH, index=False)

print("Đã lưu luật Apriori tại:", OUTPUT_PATH)
# Out:
# Đã lưu luật Apriori tại: ../data/apriori_rules.csv

# %% [markdown]
# ## Kết luận & Insight kinh doanh
#
# - Các luật Apriori cho thấy những nhóm sản phẩm thường xuyên được mua cùng nhau.
# - Một số luật có confidence và lift cao chứng tỏ mối quan hệ mua kèm mạnh.
# - Các insight này có thể được áp dụng trong việc:
#   - Gợi ý sản phẩm (recommendation)
#   - Thiết kế combo bán hàng
#   - Tối ưu trưng bày sản phẩm trong cửa hàng
